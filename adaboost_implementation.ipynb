# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.DataFrame(columns=['X1','X2','label'])
df['X1'] = np.random.random_integers(0, 10, size=100)
df['X2'] = np.random.random_integers(0, 10, size=100)
df['label'] = np.random.choice([0,1], size=100)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1820\1480915816.py:2: DeprecationWarning: This function is deprecated. Please call randint(0, 10 + 1) instead
#   df['X1'] = np.random.random_integers(0, 10, size=100)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1820\1480915816.py:3: DeprecationWarning: This function is deprecated. Please call randint(0, 10 + 1) instead
#   df['X2'] = np.random.random_integers(0, 10, size=100)
#     X1  X2  label
# 0    0   2      1
# 1    1  10      0
# 2    8   8      1
# 3    2   4      0
# 4    1   7      1
# ..  ..  ..    ...
# 95   6   2      1
# 96  10   6      1
# 97   0   1      1
# 98  10   4      0
# 99   0   7      1
#
# [100 rows x 3 columns]

# %%
import seaborn as sns
sns.scatterplot(data=df, x='X1', y='X2', hue='label')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['weights'] = 1/df.shape[0]

# %%
from sklearn.tree import DecisionTreeClassifier
dt1 = DecisionTreeClassifier(max_depth=3, random_state=46)
X = df.iloc[:,0:2].values
y = df.iloc[:,2].values
#Train 1st model
dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=46)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5416666666666666, 0.875, 'x[1] <= 8.5\ngini = 0.497\nsamples = 100\nvalue = [54, 46]'),
#  Text(0.3333333333333333, 0.625, 'x[1] <= 5.5\ngini = 0.5\nsamples = 77\nvalue = [38.0, 39.0]'),
#  Text(0.4375, 0.75, 'True  '),
#  Text(0.16666666666666666, 0.375, 'x[0] <= 5.5\ngini = 0.491\nsamples = 53\nvalue = [30, 23]'),
#  Text(0.08333333333333333, 0.125, 'gini = 0.498\nsamples = 32\nvalue = [15, 17]'),
#  Text(0.25, 0.125, 'gini = 0.408\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.5, 0.375, 'x[0] <= 1.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.4166666666666667, 0.125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5833333333333334, 0.125, 'gini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.75, 0.625, 'x[0] <= 3.5\ngini = 0.423\nsamples = 23\nvalue = [16, 7]'),
#  Text(0.6458333333333333, 0.75, '  False'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
# ...

# %%
plot_decision_regions(X, y, clf=dt1, legend=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_decision_regions(X, y, clf=dt1, legend=2)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlxtend\plotting\decision_regions.py:244, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     234 cset = ax.contourf(xx, yy, Z,
#     235                    colors=colors,
#     236                    levels=np.arange(Z.max() + 2) - 0.5,
#     237                    **contourf_kwargs)
#     239 ax.contour(xx, yy, Z, cset.levels,
#     240            colors='k',
#     241            linewidths=0.5,
#     242            antialiased=True)
# ...

# %%
df['y_pred'] = dt1.predict(X)
df
# Out:
#     X1  X2  label  weights  y_pred
# 0    0   2      1     0.01       1
# 1    1  10      0     0.01       0
# 2    8   8      1     0.01       1
# 3    2   4      0     0.01       1
# 4    1   7      1     0.01       1
# ..  ..  ..    ...      ...     ...
# 95   6   2      1     0.01       0
# 96  10   6      1     0.01       1
# 97   0   1      1     0.01       1
# 98  10   4      0     0.01       0
# 99   0   7      1     0.01       1
#
# [100 rows x 5 columns]

# %%
def calculate_model_weight(error):
 return 0.5*np.log((1-error)/(error))

# %%
# Step 3 - calculate model weight
alpha1 = calculate_model_weight(0.02)
alpha1
# Out:
# np.float64(1.9459101490553132)

# %%
# Step 4 - Update weights
def update_row_weights(row,alpha=1.945):
  if row['label'] == row['y_pred']:
    return row['weights'] * np.exp(-alpha)
  else:
    return row['weights'] * np.exp(alpha)

# %%
df['updated_weights'] = df.apply(update_row_weights,axis=1)
df['updated_weights'].sum()
df['nomalized_weights'] = df['updated_weights']/df['updated_weights'].sum()

# %%
df['nomalized_weights'].sum()
# Out:
# np.float64(1.0000000000000002)

# %%
df['cumsum_upper'] = np.cumsum(df['nomalized_weights'])
df['cumsum_lower'] = df['cumsum_upper'] - df['nomalized_weights']
df
# Out:
#     X1  X2  label  weights  y_pred  updated_weights  nomalized_weights  \
# 0    0   2      1     0.01       1         0.001430           0.000563
# 1    1  10      0     0.01       0         0.001430           0.000563
# 2    8   8      1     0.01       1         0.001430           0.000563
# 3    2   4      0     0.01       1         0.069936           0.027526
# 4    1   7      1     0.01       1         0.001430           0.000563
# ..  ..  ..    ...      ...     ...              ...                ...
# 95   6   2      1     0.01       0         0.069936           0.027526
# 96  10   6      1     0.01       1         0.001430           0.000563
# 97   0   1      1     0.01       1         0.001430           0.000563
# 98  10   4      0     0.01       0         0.001430           0.000563
# 99   0   7      1     0.01       1         0.001430           0.000563
#
#     cumsum_upper  cumsum_lower
# 0       0.000563      0.000000
# 1       0.001126      0.000563
# ...

# %%
def create_new_dataset(df):

  indices = []

  for i in range(df.shape[0]):
    a = np.random.random()
    for index,row in df.iterrows():
      if row['cumsum_upper'] > a and a > row['cumsum_lower']:
        indices.append(index)
  return indices

# %%
index_values = create_new_dataset(df)
index_values
# Out:
# [79,
#  68,
#  74,
#  7,
#  14,
#  33,
#  44,
#  52,
#  3,
#  74,
#  82,
#  7,
#  3,
#  52,
#  82,
#  87,
#  74,
#  7,
#  47,
#  30,
#  67,
#  74,
#  45,
#  81,
#  31,
#  86,
#  14,
#  67,
#  56,
#  60,
#  40,
#  79,
#  70,
#  86,
#  60,
#  60,
#  47,
#  42,
#  31,
#  56,
#  40,
#  87,
#  70,
#  46,
#  83,
#  57,
#  11,
#  11,
#  9,
#  14,
#  30,
#  93,
#  45,
#  11,
#  52,
#  62,
#  49,
#  7,
#  56,
#  70,
#  47,
#  7,
#  93,
#  87,
#  7,
#  74,
#  86,
#  34,
#  11,
#  68,
#  91,
#  57,
#  49,
#  30,
#  34,
#  39,
#  7,
#  87,
#  87,
#  53,
#  60,
#  30,
#  33,
#  52,
#  86,
#  34,
#  86,
#  3,
#  46,
#  3,
#  3,
#  34,
#  91,
#  56,
#  93,
#  30,
#  14,
#  13,
#  82,
#  3]

# %%
second_df = df.iloc[index_values,[0,1,2,3]]

dt2 = DecisionTreeClassifier(max_depth=1)

X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values
dt2.fit(X,y)

plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 8.5\ngini = 0.375\nsamples = 100\nvalue = [75, 25]'),
#  Text(0.25, 0.25, 'gini = 0.242\nsamples = 85\nvalue = [73, 12]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.625, 0.5, '  False')]

# %%
second_df['y_pred'] = dt2.predict(X)
second_df
# Out:
#     X1  X2  label  weights  y_pred
# 79   4   3      0     0.01       0
# 68   6  10      1     0.01       1
# 74   3   2      0     0.01       0
# 7    2   8      0     0.01       0
# 14   0   0      0     0.01       0
# ..  ..  ..    ...      ...     ...
# 30   8   6      0     0.01       0
# 14   0   0      0     0.01       0
# 13  10   8      0     0.01       0
# 82   3   5      0     0.01       0
# 3    2   4      0     0.01       0
#
# [100 rows x 5 columns]

# %%
alpha2 = calculate_model_weight(0.01)
alpha2
# Out:
# np.float64(2.297559925067295)

# %%
# Update weights
def update_row_weights(row,alpha=1.09):
  if row['label'] == row['y_pred']:
    return row['weights'] * np.exp(-alpha)
  else:
    return row['weights'] * np.exp(alpha)

# %%
second_df['updated_weights'] = second_df.apply(update_row_weights,axis=1)
second_df
# Out:
#     X1  X2  label  weights  y_pred  updated_weights
# 79   4   3      0     0.01       0         0.003362
# 68   6  10      1     0.01       1         0.003362
# 74   3   2      0     0.01       0         0.003362
# 7    2   8      0     0.01       0         0.003362
# 14   0   0      0     0.01       0         0.003362
# ..  ..  ..    ...      ...     ...              ...
# 30   8   6      0     0.01       0         0.003362
# 14   0   0      0     0.01       0         0.003362
# 13  10   8      0     0.01       0         0.003362
# 82   3   5      0     0.01       0         0.003362
# 3    2   4      0     0.01       0         0.003362
#
# [100 rows x 6 columns]

# %%
second_df['nomalized_weights'] = second_df['updated_weights']/second_df['updated_weights'].sum()

second_df['nomalized_weights'].sum()
# Out:
# np.float64(1.0000000000000002)

# %%
second_df['cumsum_upper'] = np.cumsum(second_df['nomalized_weights'])
second_df['cumsum_lower'] = second_df['cumsum_upper'] - second_df['nomalized_weights']
second_df[['X1','X2','label','weights','y_pred','nomalized_weights','cumsum_lower','cumsum_upper']]
# Out:
#     X1  X2  label  weights  y_pred  nomalized_weights  cumsum_lower  \
# 79   4   3      0     0.01       0           0.004765      0.000000
# 68   6  10      1     0.01       1           0.004765      0.004765
# 74   3   2      0     0.01       0           0.004765      0.009531
# 7    2   8      0     0.01       0           0.004765      0.014296
# 14   0   0      0     0.01       0           0.004765      0.019061
# ..  ..  ..    ...      ...     ...                ...           ...
# 30   8   6      0     0.01       0           0.004765      0.976173
# 14   0   0      0     0.01       0           0.004765      0.980939
# 13  10   8      0     0.01       0           0.004765      0.985704
# 82   3   5      0     0.01       0           0.004765      0.990469
# 3    2   4      0     0.01       0           0.004765      0.995235
#
#     cumsum_upper
# 79      0.004765
# 68      0.009531
# 74      0.014296
# 7       0.019061
# 14      0.023827
# ..           ...
# 30      0.980939
# ...

# %% [markdown]
# Prediction

# %%
query = np.array([9,9]).reshape(1,2)
dt1.predict(query)
# Out:
# array([1])

# %%
dt2.predict(query)
# Out:
# array([1])

# %%
alpha1*(1) + alpha2*(1)
# Out:
# np.float64(4.243470074122608)

# %%
np.sign(4.24)
# Out:
# np.float64(1.0)
